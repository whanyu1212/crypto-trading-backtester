# %%
import crypto_trading_backtester as ctb

# %%
ctb.load_crypto_data('fmp','BTCUSD')
# Out:
# 2024-07-30 11:46:47.843 | SUCCESS  | crypto_trading_backtester.data_loader.loaders.fmp_loader:fetch_all_cryptos:36 - Request for fetching cryptocurrency list was successful
# 2024-07-30 11:46:49.479 | SUCCESS  | crypto_trading_backtester.data_loader.loaders.fmp_loader:fetch_crypto_pricing:85 - Request for BTCUSD pricing data was successful
#             date       open      high       low     close     adjClose  \
# 0     2019-07-31  10089.970  10497.00   9881.00  10405.94  10405.94000
# 1     2019-08-01  10404.410  10670.00  10321.42  10533.01  10533.01000
# 2     2019-08-02  10533.620  10922.08  10500.00  10820.76  10820.76000
# 3     2019-08-03  10822.090  11089.74  10572.00  10977.51  10977.51000
# 4     2019-08-04  10977.980  11950.00  10977.98  11819.49  11819.49000
# ...          ...        ...       ...       ...       ...          ...
# 1822  2024-07-26  65794.200  68333.00  65705.60  67921.49  67912.06250
# ...
